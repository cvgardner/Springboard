# %%
from instagram_web_api import Client, ClientCompatPatch, ClientError, ClientLoginError
import pandas as pd

# %%
web_api = Client(auto_patch=True, drop_incompat_keys=False)
user_feed_info = web_api.user_feed('329452045', count=10)

# %%
help(web_api)
# Out:
# Help on Client in module instagram_web_api.client object:
#
# class Client(builtins.object)
#  |  Main API client class for the web api.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, user_agent=None, **kwargs)
#  |      :param user_agent: Override the default useragent string with your own
#  |      :param kwargs: See below
#  |
#  |      :Keyword Arguments:
#  |          - **auto_patch**: Patch the api objects to match the public API. Default: False
#  |          - **drop_incompat_key**: Remove api object keys that is not in the public API. Default: False
#  |          - **timeout**: Timeout interval in seconds. Default: 10
#  |          - **username**: Login username
#  |          - **password**: Login password
#  |          - **authenticate**: Do login on init
#  |          - **cookie**: Saved cookie string from a previous session
#  |          - **settings**: A dict of settings from a previous session
#  |          - **on_login**: Callback after successful login
#  |          - **proxy**: Specify a proxy ex: 'http://127.0.0.1:8888' (ALPHA)
#  |      :return:
#  |
#  |  delete_comment(self, media_id, comment_id)
#  |      Delete a comment. Login required.
#  |
#  |      :param media_id: Media id
#  |      :param comment_id: Comment id
#  |      :return:
#  |          .. code-block:: javascript
#  |
#  |              {"status": "ok"}
#  |
#  |  delete_like(self, media_id)
#  |      Unlike an update. Login required.
#  |
#  |      :param media_id: Media id
#  |      :return:
#  |          .. code-block:: javascript
#  |
#  |              {"status": "ok"}
#  |
#  |  friendships_create(self, user_id)
#  |      Follow a user. Login required.
#  |
#  |      :param user_id: User id
#  |      :return:
#  |          .. code-block:: javascript
#  |
#  |              {"status": "ok", "result": "following"}
#  |
#  |  friendships_destroy(self, user_id)
#  |      Unfollow a user. Login required.
#  |
#  |      :param user_id:
#  |      :return:
#  |          .. code-block:: javascript
#  |
#  |              {"status": "ok"}
#  |
#  |  get_cookie_value(self, key)
#  |
#  |  init(self)
#  |      Make a HEAD request to get the first csrf token
#  |
#  |  location_feed(self, location_id, **kwargs)
#  |      Get a location feed.
#  |
#  |      :param location_id:
#  |      :param kwargs:
#  |          - **max_id**: For pagination
#  |      :return:
#  |
#  |  login(self)
#  |      Login to the web site.
#  |
#  |  media_comments(self, short_code, **kwargs)
#  |      Get media comments
#  |
#  |      :param short_code:
#  |      :param kwargs:
#  |          - **count**: Number of comments to return. Default: 16. Maximum: 1000
#  |          - **end_cursor**: For pagination
#  |          - **extract**: bool. Return a simple list of comments
#  |      :return:
#  |
#  |  media_info(self, short_code, **kwargs)
#  |      OBSOLETE. Get media info. Does not properly extract carousel media.
#  |
#  |      :param short_code: A media's shortcode
#  |      :param kwargs:
#  |      :return:
#  |
#  |  media_info2(self, short_code)
#  |      Alternative method to get media info. This method works for carousel media.
#  |
#  |      :param short_code: A media's shortcode
#  |      :param kwargs:
#  |      :return:
#  |
#  |  post_comment(self, media_id, comment_text)
#  |      Post a new comment. Login required.
#  |
#  |      :param media_id: Media id (all numeric format, without _userid)
#  |      :param comment_text: Comment text
#  |      :return:
#  |          .. code-block:: javascript
#  |
#  |              {
#  |                  "created_time": 1483096000,
#  |                  "text": "This is a comment",
#  |                  "status": "ok",
#  |                  "from": {
#  |                      "username": "somebody",
#  |                      "profile_picture": "https://igcdn-photos-b-a.akamaihd.net/something.jpg",
#  |                      "id": "1234567890",
#  |                      "full_name": "Somebody"
#  |                  },
#  |                  "id": "1785811280000000"
#  |              }
#  |
#  |  post_like(self, media_id)
#  |      Like an update. Login required.
#  |
#  |      :param media_id: Media id
#  |      :return:
#  |          .. code-block:: javascript
#  |
#  |              {"status": "ok"}
#  |
#  |  post_photo(self, photo_data, caption='')
#  |      Post a photo
#  |
#  |      :param photo_data: byte string of the image
#  |      :param caption: caption text
#  |
#  |  search(self, query_text)
#  |      General search
#  |
#  |      :param query_text: Search text
#  |      :return:
#  |
#  |  tag_feed(self, tag, **kwargs)
#  |      Get a tag feed.
#  |
#  |      :param tag:
#  |      :param kwargs:
#  |          - **max_id**: For pagination
#  |      :return:
#  |
#  |  user_feed(self, user_id, **kwargs)
#  |      Get user feed
#  |
#  |      :param user_id:
#  |      :param kwargs:
#  |          - **count**: Number of items to return. Default: 16
#  |          - **end_cursor**: For pagination. Taken from:
#  |
#  |              .. code-block:: python
#  |
#  |                  info.get('data', {}).get('user', {}).get(
#  |                      'edge_owner_to_timeline_media', {}).get(
#  |                      'page_info', {}).get('end_cursor')
#  |          - **extract**: bool. Return a simple list of media
#  |      :return:
#  |
#  |  user_followers(self, user_id, **kwargs)
#  |      Get a user's followers. Login required.
#  |
#  |      :param user_id: User id of account
#  |      :param kwargs:
#  |          - **count**: Number of followers. Default: 10
#  |          - **end_cursor**: For pagination
#  |          - **extract**: bool. Return a simple list of users
#  |      :return:
#  |
#  |  user_following(self, user_id, **kwargs)
#  |      Get user's followings. Login required.
#  |
#  |      :param user_id: User id of account
#  |      :param kwargs:
#  |          - **count**: Number of followings. Default: 10
#  |          - **end_cursor**: For pagination
#  |          - **extract**: bool. Return a simple list of users
#  |      :return:
#  |
#  |  user_info(self, user_id, **kwargs)
#  |      OBSOLETE. Get user info.
#  |
#  |      :param user_id: User id
#  |      :param kwargs:
#  |      :return:
#  |
#  |  user_info2(self, user_name, **kwargs)
#  |      Get user info.
#  |
#  |      :param username: User name (not numeric ID)
#  |      :param kwargs:
#  |      :return:
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  authenticated_user_id
#  |      The current authenticated user id
#  |
#  |  authenticated_user_name
#  |      The current authenticated user name. No longer available.
#  |
#  |  cookie_jar
#  |
#  |  csrftoken
#  |      The client's current csrf token
#  |
#  |  is_authenticated
#  |
#  |  settings
#  |      Helper property that extracts the settings that you should cache
#  |      in addition to username and password.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  API_URL = 'https://www.instagram.com/query/'
#  |
#  |  GRAPHQL_API_URL = 'https://www.instagram.com/graphql/query/'
#  |
#  |  MOBILE_USER_AGENT = 'Mozilla/5.0 (iPhone; CPU iPhone OS 9_1 like Mac ....
#  |
#  |  USER_AGENT = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) ...(KHTM...

# %%
garyvee = web_api.user_info2('garyvee', count =10)
garyvee_feed = web_api.user_feed(garyvee['id'], count=10)
for post in garyvee_feed:
    print (post['node'])
# Out:
# {'id': '1631271246485565469_1697296', '__typename': 'GraphImage', 'edge_media_to_caption': {'edges': [{'node': {'text': "If your doing this to buy shit or look cool in front of others .. you've got no fucking shot! Love the game, the grind, the bad moments and watch your accomplishments GROW"}}]}, 'shortcode': 'BajcI5LFLAd', 'edge_media_to_comment': {'count': 1308}, 'comments_disabled': False, 'taken_at_timestamp': 1508682708, 'dimensions': {'height': 1080, 'width': 1080}, 'display_url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/
 'images': {'standard_resolution': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e15/22708832_475940876110457_7447277380625760256_n.jpg', 'width': 750, 'height': 750}, 'low_resolution': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e15/p320x320/22708832_475940876110457_7447277380625760256_n.jpg'}, 'thumbnail': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e15/s150x150/22708832_475940876110457_7447277380625760256_n.jpg'}}, 'likes': {'count': 82307, 'data': []}, 'comments': {'count': 4199, 'data': []}, 'location': None, 'created_time': '1508608308', 'users_in_photo': []}
# {'id': '1630553993465248028_1697296', '__typename': 'GraphImage', 'edge_media_to_caption': {'edges': [{'node': {'text': 'Stunned at so many people\'s behaviors on social. Will never understand why someone thinks they are special because of their followers count or the blue fucking check or because someone cool replied or liked their post. The stunning amount of people who aren\'t "growing" because they haven\'t replied to a DM or in their comments section in months is staggering .. who the fuck do you think you are? Always be grateful for every follow, every reply, every interaction!'}}]}, 'shortcode': 'Bag5DfPlzkc', 'edge_media_to_comment': {'count': 2400}, 'comments_disabled': False, 'taken_at_timestamp': 1508597204, 'dimensions': {'height': 1080, 'width': 1080}, 'display_url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/22638848_280194365826364_3890312717369606144_n.jpg', 'edge_liked_by': {'count': 50283}, 'owner': {'id': '1697296'}, 'thumbnail_src': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/22638848_280194365826364_3890312717369606144_n.jpg', 'is_video': False, 'link': 'https://www.instagram.com/p/Bag5DfPlzkc/', 'caption': {'text': 'Stunned at so many people\'s behaviors on social. Will never understand why someone thinks they are special because of their followers count or the blue fucking check or because someone cool replied or liked their post. The stunning amount of people who aren\'t "growing" because they haven\'t replied to a DM or in their comments section in months is staggering .. who the fuck do you think you are? Always be grateful for every follow, every reply, every interaction!', 'from': {'id': '1697296'}, 'id': '883756444320'}, 'tags': [], 'filter': '', 'attribution': None, 'user_has_liked': False, 'user': {'id': '1697296'}, 'type': 'image', 'images': {'standard_resolution': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/22638848_280194365826364_3890312717369606144_n.jpg', 'width': 1080, 'height': 1080}, 'low_resolution': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/p320x320/22638848_280194365826364_3890312717369606144_n.jpg'}, 'thumbnail': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/s150x150/22638848_280194365826364_3890312717369606144_n.jpg'}}, 'likes': {'count': 50283, 'data': []}, 'comments': {'count': 2400, 'data': []}, 'location': None, 'created_time': '1508597204', 'users_in_photo': []}
# {'id': '1630136236055627145_1697296', '__typename': 'GraphImage', 'edge_media_to_caption': {'edges': [{'node': {'text': "Once you understand Self Awareness things can really click in, we all can do shit and we all suck at shit .. focus on You and don't apologize"}}]}, 'shortcode': 'BafaEUVloWJ', 'edge_media_to_comment': {'count': 1290}, 'comments_disabled': False, 'taken_at_timestamp': 1508547404, 'dimensions': {'height': 1080, 'width': 1080}, 'display_url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/22708890_145125146106335_7768561129302786048_n.jpg', 'edge_liked_by': {'count': 53595}, 'owner': {'id': '1697296'}, 'thumbnail_src': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/22708890_145125146106335_7768561129302786048_n.jpg', 'is_video': False, 'link': 'https://www.instagram.com/p/BafaEUVloWJ/', 'caption': {'text': "Once you understand Self Awareness things can really click in, we all can do shit and we all suck at shit .. focus on You and don't apologize", 'from': {'id': '1697296'}, 'id': '40342073370'}, 'tags': [], 'filter': '', 'attribution': None, 'user_has_liked': False, 'user': {'id': '1697296'}, 'type': 'image', 'images': {'standard_resolution': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/22708890_145125146106335_7768561129302786048_n.jpg', 'width': 1080, 'height': 1080}, 'low_resolution': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/p320x320/22708890_145125146106335_7768561129302786048_n.jpg'}, 'thumbnail': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/s150x150/22708890_145125146106335_7768561129302786048_n.jpg'}}, 'likes': {'count': 53595, 'data': []}, 'comments': {'count': 1290, 'data': []}, 'location': None, 'created_time': '1508547404', 'users_in_photo': []}
# {'id': '1629914506842302566_1697296', '__typename': 'GraphImage', 'edge_media_to_caption': {'edges': [{'node': {'text': "... This was the theme of today's Vlog #DailyVee is linked in my profile! 👍🏻"}}]}, 'shortcode': 'Baenpu6l2hm', 'edge_media_to_comment': {'count': 1846}, 'comments_disabled': False, 'taken_at_timestamp': 1508520972, 'dimensions': {'height': 1080, 'width': 1080}, 'display_url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/
n.jpg'}, 'thumbnail': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e15/s150x150/22637606_1476311152483101_6047226631787905024_n.jpg'}}, 'likes': {'count': 39814, 'data': []}, 'comments': {'count': 1028, 'data': []}, 'location': None, 'created_time': '1508453234', 'users_in_photo': []}
# {'id': '1629162385985338464_1697296', '__typename': 'GraphImage', 'edge_media_to_caption': {'edges': [{'node': {'text': 'Find out what I mean in the new episode of my vlog ... link in my profile'}}]}, 'shortcode': 'Bab8o7yFXxg', 'edge_media_to_comment': {'count': 1520}, 'comments_disabled': False, 'taken_at_timestamp': 1508431312, 'dimensions': {'height': 1080, 'width': 1080}, 'display_url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/22580672_1489154501121209_1273539463477198848_n.jpg', 'edge_liked_by': {'count': 44935}, 'owner': {'id': '1697296'}, 'thumbnail_src': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/22580672_1489154501121209_1273539463477198848_n.jpg', 'is_video': False, 'link': 'https://www.instagram.com/p/Bab8o7yFXxg/', 'caption': {'text': 'Find out what I mean in the new episode of my vlog ... link in my profile', 'from': {'id': '1697296'}, 'id': '308585418340'}, 'tags': [], 'filter': '', 'attribution': None, 'user_has_liked': False, 'user': {'id': '1697296'}, 'type': 'image', 'images': {'standard_resolution': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/22580672_1489154501121209_1273539463477198848_n.jpg', 'width': 1080, 'height': 1080}, 'low_resolution': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/p320x320/22580672_1489154501121209_1273539463477198848_n.jpg'}, 'thumbnail': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e35/s150x150/22580672_1489154501121209_1273539463477198848_n.jpg'}}, 'likes': {'count': 44935, 'data': []}, 'comments': {'count': 1520, 'data': []}, 'location': None, 'created_time': '1508431312', 'users_in_photo': []}
# {'id': '1629043667997405212_1697296', '__typename': 'GraphVideo', 'edge_media_to_caption': {'edges': [{'node': {'text': 'Simple Question ... watch the whole video before you answer ... ❤️❤️'}}]}, 'shortcode': 'BabhpXClbAc', 'edge_media_to_comment': {'count': 2205}, 'comments_disabled': False, 'taken_at_timestamp': 1508417209, 'dimensions': {'height': 750, 'width': 750}, 'display_url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e15/22636821_879870952166089_2437966128908075008_n.jpg', 'edge_liked_by': {'count': 51684}, 'owner': {'id': '1697296'}, 'thumbnail_src': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/s640x640/e15/22636821_879870952166089_2437966128908075008_n.jpg', 'is_video': True, 'video_view_count': 379794, 'link': 'https://www.instagram.com/p/BabhpXClbAc/', 'caption': {'text': 'Simple Question ... watch the whole video before you answer ... ❤️❤️', 'from': {'id': '1697296'}, 'id': '96284896664'}, 'tags': [], 'filter': '', 'attribution': None, 'user_has_liked': False, 'user': {'id': '1697296'}, 'type': 'video', 'images': {'standard_resolution': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e15/22636821_879870952166089_2437966128908075008_n.jpg', 'width': 750, 'height': 750}, 'low_resolution': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e15/p320x320/22636821_879870952166089_2437966128908075008_n.jpg'}, 'thumbnail': {'url': 'https://scontent-lax3-2.cdninstagram.com/t51.2885-15/e15/s150x150/22636821_879870952166089_2437966128908075008_n.jpg'}}, 'likes': {'count': 51684, 'data': []}, 'comments': {'count': 2205, 'data': []}, 'location': None, 'created_time': '1508417209', 'users_in_photo': []}

# %%
pd.fromcsv("C:\Users\Christopher Gardner\Documents\Python Scripts\Top-1000-Celebrity-Twitter-Accounts.csv")
# Out:
#   File "<ipython-input-7-9ee85bec959f>", line 1
#     pd.fromcsv("C:\Users\Christopher Gardner\Documents\Python Scripts\Top-1000-Celebrity-Twitter-Accounts.csv")
#               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
